# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64ba769c519bb2ddd723f1c4ee3de8c0

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 609

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 1 | atar
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | aykhal
# Processing Record 8 of Set 1 | gornopravdinsk
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | yatou
# Processing Record 12 of Set 1 | katherine
# Processing Record 13 of Set 1 | katobu
# Processing Record 14 of Set 1 | mareeba
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | biltine
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | auki
# Processing Record 23 of Set 1 | naze
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | saint-joseph
# Processing Record 27 of Set 1 | ixtapa
# Processing Record 28 of Set 1 | salalah
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | ocosingo
# Processing Record 31 of Set 1 | fushe-arrez
# Processing Record 32 of Set 1 | dudinka
# Processing Record 33 of Set 1 | rawlins
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | eslov
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | northam
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 49 of Set 1 | kloulklubed
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | alyangula
# Processing Record 2 of Set 2 | fairbanks
# Processing Record 3 of Set 2 | coihaique
# Processing Record 4 of Set 2 | ossora
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | ziniare
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | constantine
# Processing Record 13 of Set 2 | sorland
# Processing Record 14 of Set 2 | meulaboh
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | hami
# Processing Record 19 of Set 2 | keetmanshoop
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | seoul
# Processing Record 24 of Set 2 | krasnoselkup
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | mehamn
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | lorengau
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | linguere
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | grindavik
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | carutapera
# Processing Record 38 of Set 2 | pangnirtung
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | aklavik
# Processing Record 41 of Set 2 | port hawkesbury
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | kazachinskoye
# Processing Record 44 of Set 2 | yar-sale
# Processing Record 45 of Set 2 | morros
# Processing Record 46 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | minsk
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | mikkeli
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 3 | mapiripan
# Processing Record 5 of Set 3 | yining
# Processing Record 6 of Set 3 | murgeni
# Processing Record 7 of Set 3 | lazaro cardenas
# Processing Record 8 of Set 3 | khani
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | chitipa
# Processing Record 11 of Set 3 | kupang
# Processing Record 12 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 3 | sikonge
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | kholmy
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | progreso
# Processing Record 19 of Set 3 | klyuchi
# Processing Record 20 of Set 3 | xifeng
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | kieta
# Processing Record 23 of Set 3 | kenai
# Processing Record 24 of Set 3 | anadyr
# Processing Record 25 of Set 3 | sibu
# Processing Record 26 of Set 3 | nouadhibou
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | mataura
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | umba
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | sakaiminato
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | boende
# Processing Record 36 of Set 3 | prince george
# Processing Record 37 of Set 3 | vertou
# Processing Record 38 of Set 3 | maneadero
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | yerbogachen
# Processing Record 41 of Set 3 | castellammare del golfo
# Processing Record 42 of Set 3 | pinhao
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | kulhudhuffushi
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | acara
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | tucurui
# Processing Record 4 of Set 4 | yulara
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | kununurra
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | hastings
# Processing Record 10 of Set 4 | soldotna
# Processing Record 11 of Set 4 | vardo
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | abu samrah
# Processing Record 15 of Set 4 | lerwick
# Processing Record 16 of Set 4 | egvekinot
# Processing Record 17 of Set 4 | severo-kurilsk
# Processing Record 18 of Set 4 | tibacuy
# Processing Record 19 of Set 4 | vallenar
# Processing Record 20 of Set 4 | eureka
# Processing Record 21 of Set 4 | zimovniki
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | parati
# Processing Record 24 of Set 4 | maragogi
# Processing Record 25 of Set 4 | coahuayana
# Processing Record 26 of Set 4 | mount hagen
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | sisimiut
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | mayakonda
# Processing Record 33 of Set 4 | laguna
# Processing Record 34 of Set 4 | bourail
# Processing Record 35 of Set 4 | hermanus
# Processing Record 36 of Set 4 | puerto narino
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | pangkalanbuun
# Processing Record 39 of Set 4 | tautira
# Processing Record 40 of Set 4 | mackenzie
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | prokhorovka
# Processing Record 43 of Set 4 | barra da estiva
# Processing Record 44 of Set 4 | darnah
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | itaqui
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | beringovskiy
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | velesin
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | hervey bay
# Processing Record 4 of Set 5 | yarmouth
# Processing Record 5 of Set 5 | colomi
# Processing Record 6 of Set 5 | azanka
# Processing Record 7 of Set 5 | ahipara
# Processing Record 8 of Set 5 | butaritari
# Processing Record 9 of Set 5 | sur
# Processing Record 10 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | khor
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | balaipungut
# Processing Record 15 of Set 5 | itoman
# Processing Record 16 of Set 5 | hamilton
# Processing Record 17 of Set 5 | itarema
# Processing Record 18 of Set 5 | roald
# Processing Record 19 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 5 | constitucion
# Processing Record 21 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 5 | cayenne
# Processing Record 23 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | port blair
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | qaqortoq
# Processing Record 28 of Set 5 | teya
# Processing Record 29 of Set 5 | belmonte
# Processing Record 30 of Set 5 | riviere-au-renard
# Processing Record 31 of Set 5 | esmeraldas
# Processing Record 32 of Set 5 | winona
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | danlugan
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 5 | pochutla
# Processing Record 39 of Set 5 | hambantota
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | vangaindrano
# Processing Record 43 of Set 5 | malpe
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 5 | stornoway
# Processing Record 47 of Set 5 | tsabong
# Processing Record 48 of Set 5 | swiecie
# Processing Record 49 of Set 5 | sassandra
# Processing Record 50 of Set 5 | olafsvik
# Processing Record 1 of Set 6 | teguise
# Processing Record 2 of Set 6 | huarmey
# Processing Record 3 of Set 6 | bilibino
# Processing Record 4 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 6 | the pas
# Processing Record 6 of Set 6 | jiazi
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | kronach
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | iacu
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | saint-francois
# Processing Record 14 of Set 6 | sao joao da barra
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | tura
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | cap malheureux
# Processing Record 19 of Set 6 | hammerfest
# Processing Record 20 of Set 6 | parras
# City not found. Skipping...
# Processing Record 21 of Set 6 | voyvozh
# Processing Record 22 of Set 6 | maningrida
# Processing Record 23 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 24 of Set 6 | korla
# Processing Record 25 of Set 6 | sandwick
# Processing Record 26 of Set 6 | sobolevo
# Processing Record 27 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 6 | pringsewu
# Processing Record 29 of Set 6 | teahupoo
# Processing Record 30 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 6 | richards bay
# Processing Record 32 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 6 | olinda
# Processing Record 34 of Set 6 | south lake tahoe
# Processing Record 35 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 6 | guasdualito
# Processing Record 37 of Set 6 | carandai
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | vrangel
# Processing Record 40 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 6 | tocopilla
# Processing Record 42 of Set 6 | aleksandrov gay
# Processing Record 43 of Set 6 | christchurch
# Processing Record 44 of Set 6 | leshukonskoye
# Processing Record 45 of Set 6 | sola
# Processing Record 46 of Set 6 | khatanga
# Processing Record 47 of Set 6 | visnes
# Processing Record 48 of Set 6 | jamame
# Processing Record 49 of Set 6 | arcos de la frontera
# Processing Record 50 of Set 6 | kapit
# Processing Record 1 of Set 7 | khasan
# Processing Record 2 of Set 7 | zhezkazgan
# Processing Record 3 of Set 7 | mirnyy
# Processing Record 4 of Set 7 | karimpur
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | portland
# Processing Record 7 of Set 7 | kalabo
# Processing Record 8 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 7 | okhotsk
# Processing Record 10 of Set 7 | galle
# Processing Record 11 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 7 | rocha
# Processing Record 13 of Set 7 | bud
# Processing Record 14 of Set 7 | serebriya
# Processing Record 15 of Set 7 | kardla
# Processing Record 16 of Set 7 | rajapolah
# Processing Record 17 of Set 7 | lata
# Processing Record 18 of Set 7 | ambajogai
# Processing Record 19 of Set 7 | hare bay
# Processing Record 20 of Set 7 | chicama
# Processing Record 21 of Set 7 | ostrovnoy
# Processing Record 22 of Set 7 | bolobo
# Processing Record 23 of Set 7 | monster
# Processing Record 24 of Set 7 | stephenville
# Processing Record 25 of Set 7 | albion
# Processing Record 26 of Set 7 | bentiu
# Processing Record 27 of Set 7 | kysyl-syr
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | henties bay
# Processing Record 30 of Set 7 | taoudenni
# Processing Record 31 of Set 7 | olyka
# Processing Record 32 of Set 7 | rosignol
# Processing Record 33 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 34 of Set 7 | gujan-mestras
# Processing Record 35 of Set 7 | khilok
# Processing Record 36 of Set 7 | lewistown
# Processing Record 37 of Set 7 | kismayo
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | cockburn town
# Processing Record 40 of Set 7 | florianopolis
# Processing Record 41 of Set 7 | castro marim
# Processing Record 42 of Set 7 | jatai
# Processing Record 43 of Set 7 | solano
# Processing Record 44 of Set 7 | faya
# Processing Record 45 of Set 7 | igrim
# Processing Record 46 of Set 7 | diego de almagro
# Processing Record 47 of Set 7 | bumba
# Processing Record 48 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | vagur
# Processing Record 50 of Set 7 | waipawa
# Processing Record 1 of Set 8 | prado
# Processing Record 2 of Set 8 | huai thalaeng
# Processing Record 3 of Set 8 | metabetchouan
# City not found. Skipping...
# Processing Record 4 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | jacksonville
# Processing Record 7 of Set 8 | lincoln
# Processing Record 8 of Set 8 | necochea
# Processing Record 9 of Set 8 | caninde de sao francisco
# Processing Record 10 of Set 8 | berlevag
# Processing Record 11 of Set 8 | oxilithos
# Processing Record 12 of Set 8 | sorong
# Processing Record 13 of Set 8 | sayansk
# Processing Record 14 of Set 8 | liverpool
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | sabanalarga
# Processing Record 17 of Set 8 | seguela
# Processing Record 18 of Set 8 | gnjilane
# Processing Record 19 of Set 8 | san joaquin
# Processing Record 20 of Set 8 | mzimba
# Processing Record 21 of Set 8 | prince rupert
# Processing Record 22 of Set 8 | honningsvag
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | sakakah
# Processing Record 25 of Set 8 | dhidhdhoo
# Processing Record 26 of Set 8 | nedjo
# Processing Record 27 of Set 8 | haines junction
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | mattru
# Processing Record 30 of Set 8 | noumea
# Processing Record 31 of Set 8 | presidente epitacio
# Processing Record 32 of Set 8 | mangalia
# Processing Record 33 of Set 8 | ilo
# Processing Record 34 of Set 8 | coos bay
# Processing Record 35 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 8 | kandrian
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | vila velha
# Processing Record 39 of Set 8 | poitiers
# Processing Record 40 of Set 8 | aleysk
# Processing Record 41 of Set 8 | raga
# Processing Record 42 of Set 8 | dickinson
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | deputatskiy
# Processing Record 45 of Set 8 | aksarka
# Processing Record 46 of Set 8 | catemaco
# Processing Record 47 of Set 8 | puerto carreno
# Processing Record 48 of Set 8 | plettenberg bay
# Processing Record 49 of Set 8 | gusinoye ozero
# Processing Record 50 of Set 8 | karasjok
# Processing Record 1 of Set 9 | gazipur
# Processing Record 2 of Set 9 | ambanja
# Processing Record 3 of Set 9 | tuatapere
# Processing Record 4 of Set 9 | inirida
# Processing Record 5 of Set 9 | skibbereen
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | methoni
# Processing Record 8 of Set 9 | zhigansk
# Processing Record 9 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 9 | bria
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | port lincoln
# Processing Record 13 of Set 9 | terme
# Processing Record 14 of Set 9 | xining
# Processing Record 15 of Set 9 | ardakan
# Processing Record 16 of Set 9 | sangar
# Processing Record 17 of Set 9 | krasnik
# Processing Record 18 of Set 9 | garmsar
# Processing Record 19 of Set 9 | gazanjyk
# Processing Record 20 of Set 9 | naranjal
# Processing Record 21 of Set 9 | moose factory
# Processing Record 22 of Set 9 | barmer
# Processing Record 23 of Set 9 | elko
# Processing Record 24 of Set 9 | kutum
# Processing Record 25 of Set 9 | dois vizinhos
# Processing Record 26 of Set 9 | hazorasp
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | uyskoye
# Processing Record 29 of Set 9 | adrar
# Processing Record 30 of Set 9 | magadan
# Processing Record 31 of Set 9 | ghugus
# Processing Record 32 of Set 9 | kalispell
# Processing Record 33 of Set 9 | sal rei
# Processing Record 34 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 9 | evensk
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | bam
# Processing Record 38 of Set 9 | manggar
# Processing Record 39 of Set 9 | makakilo city
# Processing Record 40 of Set 9 | soto la marina
# Processing Record 41 of Set 9 | usinsk
# Processing Record 42 of Set 9 | kyaikto
# Processing Record 43 of Set 9 | malindi
# Processing Record 44 of Set 9 | qui nhon
# Processing Record 45 of Set 9 | tuni
# Processing Record 46 of Set 9 | gwadar
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | simbahan
# Processing Record 49 of Set 9 | esfarayen
# Processing Record 50 of Set 9 | bardiyah
# Processing Record 1 of Set 10 | acajutla
# Processing Record 2 of Set 10 | fuling
# Processing Record 3 of Set 10 | padang
# Processing Record 4 of Set 10 | jalu
# Processing Record 5 of Set 10 | storsteinnes
# Processing Record 6 of Set 10 | shangrao
# Processing Record 7 of Set 10 | whitehaven
# Processing Record 8 of Set 10 | tripoli
# Processing Record 9 of Set 10 | bafq
# Processing Record 10 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 11 of Set 10 | verkhoyansk
# Processing Record 12 of Set 10 | bahia honda
# Processing Record 13 of Set 10 | norman wells
# Processing Record 14 of Set 10 | tilichiki
# Processing Record 15 of Set 10 | impfondo
# Processing Record 16 of Set 10 | terrasini
# Processing Record 17 of Set 10 | upata
# Processing Record 18 of Set 10 | vasilkovo
# City not found. Skipping...
# Processing Record 19 of Set 10 | taksimo
# Processing Record 20 of Set 10 | nome
# Processing Record 21 of Set 10 | sturgeon falls
# Processing Record 22 of Set 10 | praia da vitoria
# Processing Record 23 of Set 10 | camapua
# Processing Record 24 of Set 10 | rio gallegos
# Processing Record 25 of Set 10 | porto walter
# Processing Record 26 of Set 10 | zyryanka
# Processing Record 27 of Set 10 | sambava
# Processing Record 28 of Set 10 | nshamba
# Processing Record 29 of Set 10 | zheleznodorozhnyy
# Processing Record 30 of Set 10 | pindobacu
# Processing Record 31 of Set 10 | svitavy
# Processing Record 32 of Set 10 | sioux lookout
# Processing Record 33 of Set 10 | santa maria
# Processing Record 34 of Set 10 | ashqelon
# Processing Record 35 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 10 | hasaki
# Processing Record 37 of Set 10 | clinton
# Processing Record 38 of Set 10 | nishihara
# Processing Record 39 of Set 10 | superior
# Processing Record 40 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 10 | zeya
# Processing Record 42 of Set 10 | koforidua
# Processing Record 43 of Set 10 | siilinjarvi
# Processing Record 44 of Set 10 | revda
# Processing Record 45 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 10 | san cristobal
# Processing Record 47 of Set 10 | hafizabad
# Processing Record 48 of Set 10 | zlitan
# Processing Record 49 of Set 10 | sidi ali
# Processing Record 50 of Set 10 | inta
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | kiunga
# Processing Record 3 of Set 11 | la macarena
# Processing Record 4 of Set 11 | baturaja
# Processing Record 5 of Set 11 | umm kaddadah
# Processing Record 6 of Set 11 | udachnyy
# Processing Record 7 of Set 11 | lashio
# Processing Record 8 of Set 11 | biella
# Processing Record 9 of Set 11 | araouane
# Processing Record 10 of Set 11 | rognan
# Processing Record 11 of Set 11 | sedam
# Processing Record 12 of Set 11 | madisonville
# Processing Record 13 of Set 11 | yinchuan
# Processing Record 14 of Set 11 | kamyshlov
# Processing Record 15 of Set 11 | seydi
# Processing Record 16 of Set 11 | ormara
# Processing Record 17 of Set 11 | daru
# Processing Record 18 of Set 11 | palmer
# Processing Record 19 of Set 11 | lundazi
# Processing Record 20 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 11 | yertsevo
# Processing Record 22 of Set 11 | beloha
# Processing Record 23 of Set 11 | bandarbeyla
# Processing Record 24 of Set 11 | mwanza
# Processing Record 25 of Set 11 | saint stephen
# Processing Record 26 of Set 11 | bosaso
# Processing Record 27 of Set 11 | opoczno
# Processing Record 28 of Set 11 | sagua la grande
# Processing Record 29 of Set 11 | marrakesh
# Processing Record 30 of Set 11 | cairns
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | lodja
# Processing Record 33 of Set 11 | rawson
# Processing Record 34 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 11 | villa del rosario
# Processing Record 36 of Set 11 | krasnaya gora
# Processing Record 37 of Set 11 | awbari
# Processing Record 38 of Set 11 | camocim
# Processing Record 39 of Set 11 | banjar
# Processing Record 40 of Set 11 | miami
# Processing Record 41 of Set 11 | pahrump
# Processing Record 42 of Set 11 | vrises
# Processing Record 43 of Set 11 | pacific grove
# Processing Record 44 of Set 11 | manacapuru
# Processing Record 45 of Set 11 | lewisporte
# Processing Record 46 of Set 11 | vestmannaeyjar
# Processing Record 47 of Set 11 | tulln
# Processing Record 48 of Set 11 | san vicente
# Processing Record 49 of Set 11 | maceio
# Processing Record 50 of Set 11 | talnakh
# Processing Record 1 of Set 12 | oistins
# Processing Record 2 of Set 12 | skjervoy
# Processing Record 3 of Set 12 | matara
# Processing Record 4 of Set 12 | shahr-e kord
# Processing Record 5 of Set 12 | timiryazevskiy
# Processing Record 6 of Set 12 | bukama
# Processing Record 7 of Set 12 | cacule
# Processing Record 8 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 12 | saint-augustin
# Processing Record 10 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 12 | vao
# Processing Record 12 of Set 12 | tambacounda
# Processing Record 13 of Set 12 | ambon
# Processing Record 14 of Set 12 | sao jose da coroa grande
# Processing Record 15 of Set 12 | port hedland
# Processing Record 16 of Set 12 | cortez
# Processing Record 17 of Set 12 | amahai
# Processing Record 18 of Set 12 | hauterive
# Processing Record 19 of Set 12 | mandalgovi
# Processing Record 20 of Set 12 | tamandare
# Processing Record 21 of Set 12 | chara
# Processing Record 22 of Set 12 | pacifica
# Processing Record 23 of Set 12 | severodvinsk
# Processing Record 24 of Set 12 | bathsheba
# Processing Record 25 of Set 12 | floridia
# Processing Record 26 of Set 12 | lavrentiya
# Processing Record 27 of Set 12 | warrington
# Processing Record 28 of Set 12 | moindou
# Processing Record 29 of Set 12 | bonavista
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | malanje
# Processing Record 32 of Set 12 | gunjur
# Processing Record 33 of Set 12 | kautokeino
# Processing Record 34 of Set 12 | antigonish
# Processing Record 35 of Set 12 | kalaleh
# Processing Record 36 of Set 12 | doba
# Processing Record 37 of Set 12 | nizhniy kuranakh
# Processing Record 38 of Set 12 | shenjiamen
# Processing Record 39 of Set 12 | narasannapeta
# Processing Record 40 of Set 12 | plainview
# Processing Record 41 of Set 12 | pontianak
# Processing Record 42 of Set 12 | mutis
# Processing Record 43 of Set 12 | nong bua
# Processing Record 44 of Set 12 | digha
# Processing Record 45 of Set 12 | mujiayingzi
# Processing Record 46 of Set 12 | chumikan
# Processing Record 47 of Set 12 | bulgan
# Processing Record 48 of Set 12 | asau
# Processing Record 49 of Set 12 | cochabamba
# Processing Record 50 of Set 12 | luanda
# Processing Record 1 of Set 13 | dong xoai
# Processing Record 2 of Set 13 | okha
# Processing Record 3 of Set 13 | effingham
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | xique-xique
# Processing Record 6 of Set 13 | barcelos
# Processing Record 7 of Set 13 | wanaka
# Processing Record 8 of Set 13 | makokou
# Processing Record 9 of Set 13 | black river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Avarua      CK -21.2078 -159.7750     80.65        65          20
# 1          Albany      US  42.6001  -73.9662     40.80        63         100
# 2            Atar      MR  20.5169  -13.0499     82.20        22          99
# 3  Saint-Philippe      RE -21.3585   55.7679     74.75        78          34
# 4          Aykhal      RU  66.0000  111.5000    -20.67       100         100
# 5  Gornopravdinsk      RU  60.0500   69.9000     21.09        93         100
# 6  Cabo San Lucas      MX  22.8909 -109.9124     74.52        75           1
# 7         Kavieng      PG  -2.5744  150.7967     82.72        74          93
# 8           Yatou      CN  37.1500  122.3833     55.92        73          99
# 9       Katherine      AU -14.4667  132.2667     95.32        38          75
#
#    Wind Speed Current Description
# 0       12.66          few clouds
# 1        4.97     overcast clouds
# 2        3.80     overcast clouds
# 3       10.29    scattered clouds
# 4        6.49     overcast clouds
# 5        9.40     overcast clouds
# 6        5.01           clear sky
# 7        8.43          light rain
# 8       15.28     overcast clouds
# 9        6.91       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
